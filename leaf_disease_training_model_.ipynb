# %%
import pandas as pd
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET = "/content/drive/MyDrive/New Plant Diseases Dataset(Augmented)/train"
DATASET2 = "/content/drive/MyDrive/New Plant Diseases Dataset(Augmented)/valid"

CATEGORIES=["Tomato___Bacterial_spot","Tomato___Early_blight","Tomato___healthy","Tomato___Late_blight","Tomato___Leaf_Mold","Tomato___Septoria_leaf_spot","Tomato___Spider_mites Two-spotted_spider_mite","Tomato___Target_Spot","Tomato___Tomato_mosaic_virus","Tomato___Tomato_Yellow_Leaf_Curl_Virus"]

train_data=[]

for category in CATEGORIES:
        label=CATEGORIES.index(category)
        path=os.path.join(DATASET,category)
        for img_file in os.listdir(path):
            img=cv.imread(os.path.join(path,img_file),1)
            img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
            img=cv.resize(img,(64,64))
            train_data.append([img,label])

test_data=[]

for category in CATEGORIES:
        label=CATEGORIES.index(category)
        path=os.path.join(DATASET2,category)
        for img_file in os.listdir(path):
            img=cv.imread(os.path.join(path,img_file),1)
            img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
            img=cv.resize(img,(64,64))
            test_data.append([img,label])

print(len(train_data))
print(len(test_data))
# Out:
# 12086
# 2308

# %%
import random

random.shuffle(train_data)
random.shuffle(test_data)

for lbl in train_data[:10]:
    print(lbl[1])

X_train=[]
y_train=[]

for features,label in train_data:
    X_train.append(features)
    y_train.append(label)

Y=[]
for i in y_train:
    if i==0:
        Y.append("BACTERIAL SPOT")
    elif i==1:
        Y.append("EARLY BLIGHT")
    elif i==2:
        Y.append("HEALTHY")
    elif i==3:
        Y.append("LATE BLIGHT")
    elif i==4:
        Y.append("LEAF MOLD")
    elif i==5:
        Y.append("SEPTORIA LEAF SPOT")
    elif i==6:
        Y.append("SPIDER MITE")
    elif i==7:
        Y.append("TARGET SPOT")
    elif i==8:
        Y.append("MOSAIC VIRUS")
    else:
        Y.append("YELLOW LEAF CURL VIRUS")

len(X_train),len(y_train)
# Out:
# 1
# 9
# 0
# 9
# 5
# 2
# 8
# 7
# 0
# 2
# (12086, 12086)

# %%
X_test=[]
y_test=[]

for features,label in test_data:
    X_test.append(features)
    y_test.append(label)

Z=[]
for i in y_test:
    if i==0:
        Z.append("BACTERIAL SPOT")
    elif i==1:
        Z.append("EARLY BLIGHT")
    elif i==2:
        Z.append("HEALTHY")
    elif i==3:
        Z.append("LATE BLIGHT")
    elif i==4:
        Z.append("LEAF MOLD")
    elif i==5:
        Z.append("SEPTORIA LEAF SPOT")
    elif i==6:
        Z.append("SPIDER MITE")
    elif i==7:
        Z.append("TARGET SPOT")
    elif i==8:
        Z.append("MOSAIC VIRUS")
    else:
        Z.append("YELLOW LEAF CURL VIRUS")

len(X_test),len(y_test)
# Out:
# (2308, 2308)

# %%
X_train=np.array(X_train).reshape(-1,64,64,3)
X_train=X_train/255.0
X_train.shape

X_test=np.array(X_test).reshape(-1,64,64,3)
X_test=X_test/255.0
X_test.shape

order=['BACTERIAL SPOT','EARLY BLIGHT','HEALTHY','LATE BLIGHT','LEAF MOLD','SEPTORIA LEAF SPOT','SPIDER MITE','TARGET SPOT','MOSAIC VIRUS','YELLOW LEAF CURL VIRUS']

ax=sns.countplot(Y, order=order)
ax.set_xlabel("Leaf Diseases")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
ax.set_ylabel("Image Count")

ax=sns.countplot(Z, order=order)
ax.set_xlabel("Leaf Diseases")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
ax.set_ylabel("Image Count")
# Out:
# <ipython-input-5-6d3f92496e00>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
# <ipython-input-5-6d3f92496e00>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
# Text(0, 0.5, 'Image Count')

# %%
from keras.utils import to_categorical

one_hot_train=to_categorical(y_train)
one_hot_train

one_hot_test=to_categorical(y_test)
one_hot_test

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,Dense,Flatten,MaxPooling2D,Dropout

classifier=Sequential()

classifier.add(Conv2D(32,(3,3), input_shape=(64,64,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.2))

classifier.add(Conv2D(64,(3,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.2))

classifier.add(Conv2D(128,(3,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.4))

classifier.add(Flatten())

classifier.add(Dense(activation='relu', units=64))
classifier.add(Dense(activation='relu', units=128))
classifier.add(Dense(activation='relu', units=64))
classifier.add(Dense(activation='softmax', units=10))

classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

classifier.summary()

hist=classifier.fit(X_train,one_hot_train,epochs=75,batch_size=128,validation_split=0.2)
classifier.save('tomato_disease_classifier.h5')

test_loss,test_acc=classifier.evaluate(X_test,one_hot_test)
test_loss,test_acc
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_3 (MaxPoolin  (None, 31, 31, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 31, 31, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 64)                294976
#
#  dense_5 (Dense)             (None, 128)               8320
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 405450 (1.55 MB)
# Trainable params: 405450 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/75
# 76/76 [==============================] - 81s 1s/step - loss: 2.0440 - accuracy: 0.2697 - val_loss: 1.7508 - val_accuracy: 0.4094
# Epoch 2/75
# 76/76 [==============================] - 80s 1s/step - loss: 1.3855 - accuracy: 0.5191 - val_loss: 1.2098 - val_accuracy: 0.5695
# Epoch 3/75
# 76/76 [==============================] - 82s 1s/step - loss: 1.0079 - accuracy: 0.6526 - val_loss: 0.8294 - val_accuracy: 0.7188
# Epoch 4/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.7636 - accuracy: 0.7351 - val_loss: 0.6179 - val_accuracy: 0.7957
# Epoch 5/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.6155 - accuracy: 0.7821 - val_loss: 0.5311 - val_accuracy: 0.8251
# Epoch 6/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.5359 - accuracy: 0.8134 - val_loss: 0.5105 - val_accuracy: 0.8234
# Epoch 7/75
# 76/76 [==============================] - 83s 1s/step - loss: 0.5111 - accuracy: 0.8179 - val_loss: 0.4786 - val_accuracy: 0.8362
# Epoch 8/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.4249 - accuracy: 0.8503 - val_loss: 0.4293 - val_accuracy: 0.8565
# Epoch 9/75
# 76/76 [==============================] - 78s 1s/step - loss: 0.3892 - accuracy: 0.8650 - val_loss: 0.3737 - val_accuracy: 0.8668
# Epoch 10/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.3608 - accuracy: 0.8741 - val_loss: 0.7318 - val_accuracy: 0.7605
# Epoch 11/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.3924 - accuracy: 0.8590 - val_loss: 0.3623 - val_accuracy: 0.8772
# Epoch 12/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.3295 - accuracy: 0.8847 - val_loss: 0.3179 - val_accuracy: 0.8908
# Epoch 13/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.2982 - accuracy: 0.8952 - val_loss: 0.3353 - val_accuracy: 0.8797
# Epoch 14/75
# 76/76 [==============================] - 79s 1s/step - loss: 0.2886 - accuracy: 0.8984 - val_loss: 0.3257 - val_accuracy: 0.8788
# Epoch 15/75
# 76/76 [==============================] - 74s 963ms/step - loss: 0.2675 - accuracy: 0.9030 - val_loss: 0.3194 - val_accuracy: 0.8854
# Epoch 16/75
# 76/76 [==============================] - 75s 989ms/step - loss: 0.2692 - accuracy: 0.9040 - val_loss: 0.3351 - val_accuracy: 0.8776
# Epoch 17/75
# 76/76 [==============================] - 79s 1s/step - loss: 0.2437 - accuracy: 0.9107 - val_loss: 0.2667 - val_accuracy: 0.9069
# Epoch 18/75
# 76/76 [==============================] - 75s 985ms/step - loss: 0.2285 - accuracy: 0.9159 - val_loss: 0.2690 - val_accuracy: 0.9090
# Epoch 19/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.2259 - accuracy: 0.9222 - val_loss: 0.3477 - val_accuracy: 0.8801
# Epoch 20/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.2086 - accuracy: 0.9215 - val_loss: 0.2664 - val_accuracy: 0.9003
# Epoch 21/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.2086 - accuracy: 0.9250 - val_loss: 0.2293 - val_accuracy: 0.9194
# Epoch 22/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.1912 - accuracy: 0.9334 - val_loss: 0.2376 - val_accuracy: 0.9177
# Epoch 23/75
# 76/76 [==============================] - 80s 1s/step - loss: 0.1809 - accuracy: 0.9331 - val_loss: 0.2771 - val_accuracy: 0.9057
# Epoch 24/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.1552 - accuracy: 0.9471 - val_loss: 0.2374 - val_accuracy: 0.9173
# Epoch 25/75
# 76/76 [==============================] - 75s 986ms/step - loss: 0.1736 - accuracy: 0.9373 - val_loss: 0.2423 - val_accuracy: 0.9160
# Epoch 26/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.1531 - accuracy: 0.9450 - val_loss: 0.2565 - val_accuracy: 0.9123
# Epoch 27/75
# 76/76 [==============================] - 76s 996ms/step - loss: 0.1604 - accuracy: 0.9427 - val_loss: 0.2273 - val_accuracy: 0.9181
# Epoch 28/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.1424 - accuracy: 0.9500 - val_loss: 0.2382 - val_accuracy: 0.9198
# Epoch 29/75
# 76/76 [==============================] - 81s 1s/step - loss: 0.1442 - accuracy: 0.9483 - val_loss: 0.2377 - val_accuracy: 0.9210
# Epoch 30/75
# 76/76 [==============================] - 76s 998ms/step - loss: 0.1545 - accuracy: 0.9428 - val_loss: 0.2754 - val_accuracy: 0.9032
# Epoch 31/75
# 76/76 [==============================] - 76s 999ms/step - loss: 0.1432 - accuracy: 0.9510 - val_loss: 0.2084 - val_accuracy: 0.9285
# Epoch 32/75
# 76/76 [==============================] - 76s 999ms/step - loss: 0.1195 - accuracy: 0.9552 - val_loss: 0.2260 - val_accuracy: 0.9264
# Epoch 33/75
# 76/76 [==============================] - 80s 1s/step - loss: 0.1117 - accuracy: 0.9614 - val_loss: 0.2007 - val_accuracy: 0.9347
# Epoch 34/75
# 76/76 [==============================] - 75s 992ms/step - loss: 0.1154 - accuracy: 0.9590 - val_loss: 0.3883 - val_accuracy: 0.8788
# Epoch 35/75
# 76/76 [==============================] - 74s 981ms/step - loss: 0.1410 - accuracy: 0.9492 - val_loss: 0.2145 - val_accuracy: 0.9251
# Epoch 36/75
# 76/76 [==============================] - 75s 995ms/step - loss: 0.0973 - accuracy: 0.9667 - val_loss: 0.2524 - val_accuracy: 0.9222
# Epoch 37/75
# 76/76 [==============================] - 80s 1s/step - loss: 0.0968 - accuracy: 0.9651 - val_loss: 0.2652 - val_accuracy: 0.9103
# Epoch 38/75
# 76/76 [==============================] - 76s 997ms/step - loss: 0.1283 - accuracy: 0.9539 - val_loss: 0.2232 - val_accuracy: 0.9276
# Epoch 39/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.0890 - accuracy: 0.9661 - val_loss: 0.2162 - val_accuracy: 0.9289
# Epoch 40/75
# 76/76 [==============================] - 81s 1s/step - loss: 0.1118 - accuracy: 0.9597 - val_loss: 0.2194 - val_accuracy: 0.9285
# Epoch 41/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.0931 - accuracy: 0.9667 - val_loss: 0.2192 - val_accuracy: 0.9330
# Epoch 42/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.0939 - accuracy: 0.9650 - val_loss: 0.1871 - val_accuracy: 0.9417
# Epoch 43/75
# 76/76 [==============================] - 74s 976ms/step - loss: 0.0805 - accuracy: 0.9726 - val_loss: 0.2228 - val_accuracy: 0.9293
# Epoch 44/75
# 76/76 [==============================] - 75s 990ms/step - loss: 0.0865 - accuracy: 0.9693 - val_loss: 0.2138 - val_accuracy: 0.9347
# Epoch 45/75
# 76/76 [==============================] - 75s 995ms/step - loss: 0.0829 - accuracy: 0.9709 - val_loss: 0.2797 - val_accuracy: 0.9094
# Epoch 46/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.0931 - accuracy: 0.9681 - val_loss: 0.2519 - val_accuracy: 0.9268
# Epoch 47/75
# 76/76 [==============================] - 76s 998ms/step - loss: 0.0703 - accuracy: 0.9762 - val_loss: 0.2082 - val_accuracy: 0.9363
# Epoch 48/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.0759 - accuracy: 0.9743 - val_loss: 0.1952 - val_accuracy: 0.9396
# Epoch 49/75
# 76/76 [==============================] - 73s 969ms/step - loss: 0.0623 - accuracy: 0.9771 - val_loss: 0.2744 - val_accuracy: 0.9235
# Epoch 50/75
# 76/76 [==============================] - 74s 977ms/step - loss: 0.0815 - accuracy: 0.9708 - val_loss: 0.2357 - val_accuracy: 0.9260
# Epoch 51/75
# 76/76 [==============================] - 75s 995ms/step - loss: 0.1004 - accuracy: 0.9633 - val_loss: 0.2029 - val_accuracy: 0.9417
# Epoch 52/75
# 76/76 [==============================] - 81s 1s/step - loss: 0.0726 - accuracy: 0.9754 - val_loss: 0.2078 - val_accuracy: 0.9380
# Epoch 53/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.0780 - accuracy: 0.9719 - val_loss: 0.2610 - val_accuracy: 0.9227
# Epoch 54/75
# 76/76 [==============================] - 76s 997ms/step - loss: 0.0611 - accuracy: 0.9783 - val_loss: 0.2324 - val_accuracy: 0.9305
# Epoch 55/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.0682 - accuracy: 0.9753 - val_loss: 0.1988 - val_accuracy: 0.9388
# Epoch 56/75
# 76/76 [==============================] - 81s 1s/step - loss: 0.0782 - accuracy: 0.9724 - val_loss: 0.2558 - val_accuracy: 0.9185
# Epoch 57/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.0736 - accuracy: 0.9740 - val_loss: 0.2114 - val_accuracy: 0.9351
# Epoch 58/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.0673 - accuracy: 0.9762 - val_loss: 0.1957 - val_accuracy: 0.9413
# Epoch 59/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.0503 - accuracy: 0.9816 - val_loss: 0.2691 - val_accuracy: 0.9260
# Epoch 60/75
# 76/76 [==============================] - 75s 986ms/step - loss: 0.0673 - accuracy: 0.9771 - val_loss: 0.2090 - val_accuracy: 0.9392
# Epoch 61/75
# 76/76 [==============================] - 82s 1s/step - loss: 0.0487 - accuracy: 0.9817 - val_loss: 0.2087 - val_accuracy: 0.9396
# Epoch 62/75
# 76/76 [==============================] - 76s 997ms/step - loss: 0.0362 - accuracy: 0.9877 - val_loss: 0.1921 - val_accuracy: 0.9454
# Epoch 63/75
# 76/76 [==============================] - 74s 975ms/step - loss: 0.0597 - accuracy: 0.9791 - val_loss: 0.2185 - val_accuracy: 0.9417
# Epoch 64/75
# 76/76 [==============================] - 74s 979ms/step - loss: 0.0575 - accuracy: 0.9796 - val_loss: 0.2151 - val_accuracy: 0.9342
# Epoch 65/75
# 76/76 [==============================] - 76s 998ms/step - loss: 0.0511 - accuracy: 0.9827 - val_loss: 0.2234 - val_accuracy: 0.9342
# Epoch 66/75
# 76/76 [==============================] - 81s 1s/step - loss: 0.0551 - accuracy: 0.9811 - val_loss: 0.2244 - val_accuracy: 0.9371
# Epoch 67/75
# 76/76 [==============================] - 77s 1s/step - loss: 0.0804 - accuracy: 0.9734 - val_loss: 0.1922 - val_accuracy: 0.9483
# Epoch 68/75
# 76/76 [==============================] - 75s 991ms/step - loss: 0.0638 - accuracy: 0.9749 - val_loss: 0.1970 - val_accuracy: 0.9433
# Epoch 69/75
# 76/76 [==============================] - 81s 1s/step - loss: 0.0571 - accuracy: 0.9807 - val_loss: 0.2379 - val_accuracy: 0.9363
# Epoch 70/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.0597 - accuracy: 0.9790 - val_loss: 0.2428 - val_accuracy: 0.9351
# Epoch 71/75
# 76/76 [==============================] - 75s 992ms/step - loss: 0.0694 - accuracy: 0.9750 - val_loss: 0.2284 - val_accuracy: 0.9359
# Epoch 72/75
# 76/76 [==============================] - 74s 973ms/step - loss: 0.0707 - accuracy: 0.9747 - val_loss: 0.2119 - val_accuracy: 0.9404
# Epoch 73/75
# 76/76 [==============================] - 80s 1s/step - loss: 0.0447 - accuracy: 0.9826 - val_loss: 0.2203 - val_accuracy: 0.9413
# Epoch 74/75
# 76/76 [==============================] - 76s 1s/step - loss: 0.0411 - accuracy: 0.9863 - val_loss: 0.1888 - val_accuracy: 0.9475
# Epoch 75/75
# 76/76 [==============================] - 83s 1s/step - loss: 0.0438 - accuracy: 0.9842 - val_loss: 0.2010 - val_accuracy: 0.9475
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 73/73 [==============================] - 4s 55ms/step - loss: 0.2702 - accuracy: 0.9328
# (0.27016714215278625, 0.9328423142433167)

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Classifier Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper right')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Classifier Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.show()

y_pred = np.argmax(classifier.predict(X_test), axis=-1)
y_pred

y_prob=classifier.predict(X_test)
y_prob
# Out:
# 73/73 [==============================] - 5s 67ms/step
# 73/73 [==============================] - 5s 70ms/step
# array([[1.9249907e-03, 3.3000413e-06, 1.4092392e-07, ..., 7.8946649e-10,
#         2.2710792e-11, 9.9806941e-01],
#        [3.1115605e-06, 2.2415445e-08, 4.6101092e-12, ..., 1.2013512e-08,
#         1.9216466e-13, 9.9997932e-01],
#        [6.3450928e-10, 3.8599934e-05, 2.0020433e-07, ..., 1.8115286e-02,
#         5.3781540e-10, 2.1123450e-08],
#        ...,
#        [8.3038334e-13, 9.9962795e-01, 1.4820431e-10, ..., 5.8806279e-11,
#         2.7935249e-10, 1.3996885e-12],
#        [2.2927528e-05, 8.8786745e-01, 4.0079218e-08, ..., 2.5419701e-02,
#         2.8097580e-07, 1.2027122e-05],
#        [0.0000000e+00, 0.0000000e+00, 4.6540163e-31, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %%
from sklearn.metrics import roc_curve, auc

fpr = {}
tpr = {}
thresh ={}
roc_auc={}

n_class = 10

for i in range(n_class):
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob[:,i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.plot(fpr[0], tpr[0], color='orange',label='Bacterial Spot AUC = %0.3f' % roc_auc[0])
plt.plot(fpr[1], tpr[1], color='green',label='Early Blight AUC = %0.3f' % roc_auc[1])
plt.plot(fpr[2], tpr[2], color='blue',label='Healthy AUC = %0.3f' % roc_auc[2])
plt.plot(fpr[3], tpr[3], color='red',label='Late Blight AUC = %0.3f' % roc_auc[3])
plt.plot(fpr[4], tpr[4], color='pink',label='Leaf Mold AUC = %0.3f' % roc_auc[4])
plt.plot(fpr[5], tpr[5], color='purple',label='Septoria Leaf Spot AUC = %0.3f' % roc_auc[5])
plt.plot(fpr[6], tpr[6], color='brown',label='Spider Mites AUC = %0.3f' % roc_auc[6])
plt.plot(fpr[7], tpr[7], color='cyan',label='Target Spot AUC = %0.3f' % roc_auc[7])
plt.plot(fpr[8], tpr[8], color='yellow',label='Mosaic Virus AUC = %0.3f' % roc_auc[8])
plt.plot(fpr[9], tpr[9], color='black',label='Yellow Leaf Curl Virus AUC = %0.3f' % roc_auc[9])
plt.title('Tomato Leaves Diseases ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
